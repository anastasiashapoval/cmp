# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

x=[-3,-2,0,3]
y=[9,10,-6,15]
values=[-4,-1.5,2,2.5]
def lagrange_interpolation(x, y, z):
    n = len(x)
    p = np.zeros(n)
    for i in range(n):
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (z - x[j])/(x[i] - x[j])
        p[i] = p_i
    return np.dot(y, p)

interpolated_values = [lagrange_interpolation(x, y, z) for z in values]

for i in range(4):
  print("Значення функції у точці ", i+1, " дорівнює ", interpolated_values[i].round(4))


xnew=np.linspace(np.min(x),np.max(x),100)
ynew=[lagrange_interpolation(x,y,i) for i in xnew]

plt.plot(x,y,'o',xnew,ynew)
plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.show()

# Перевірка
f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Значення функції у точці  1  дорівнює  -6.0
# Значення функції у точці  2  дорівнює  7.125
# Значення функції у точці  3  дорівнює  -6.0
# Значення функції у точці  4  дорівнює  2.125
